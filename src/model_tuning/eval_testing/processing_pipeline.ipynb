# %%
#from pylibCZIrw import czi as pyczi
#import ipywidgets as widgets
# import json
# from matplotlib import pyplot as plt
# import matplotlib.cm as cm
# import numpy as np
# import os, sys
# from tqdm import tqdm
# from tqdm.contrib import itertools as it
# from matplotlib.patches import Rectangle
# from aicsimageio import AICSImage
# from aicsimageprocessing import resize
# from aicsimageio.writers import OmeTiffWriter
# from aicsimageio.types import PhysicalPixelSizes
import processing_tools as pt
import os

# show the used python env
#print("Using:", sys.executable)
# get current directory
path = os.getcwd()
print("Current Directory", path)
 
# prints parent directory
print(os.path.abspath(os.path.join(path, os.pardir)))
# Out:
# 25-Oct-24 16:53:54 - bfio.backends - WARNING  - Java backend is not available. This could be due to a missing dependency (jpype).
# c:\Users\mcapage1\AppData\Local\mambaforge\envs\mikala_processing\lib\site-packages\dask\dataframe\__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# Current Directory d:\Mikala\processing_pipeline\fly_ovaries_processing_pipeline\src
# d:\Mikala\processing_pipeline\fly_ovaries_processing_pipeline

# %%
# Folder containing the input data
INPUT_FOLDER = 'D:\\Mikala\\images\\raw\\10252024\\' #point to folder with the images or folder containing all the subfolders to batch process
PREPROCESSED_FOLDER = 'D:\\Mikala\\images\\preproc' #point to main folder with all the folders containing preprocessed data
OUTPUT_FOLDER = 'D:/Mikala/output/new_models' #point to main folder with all the output

targetPxSize = [0.25, 0.14, 0.14] #ZYX
channelMapping = '4321' # 1:VASA, 2:membrane, 3:TJ, 4:DAPI

#Old models
#VASA_model_path = 'D:\\Mikala\\processing_pipeline\\fly_ovaries_processing_pipeline\\models'
#VASA_model_name = 'VASA_xy_pipeline_bright_Mikala'
#TJ_model_path =  "D:\\Mikala\\processing_pipeline\\fly_ovaries_processing_pipeline\\models"
#TJ_model_name = 'TJ_xy_pipeline_norm_Mikala'

# New models as of 10222024
VASA_model_path = 'D:\\Mikala\\images\\training\\VASA\\models'
VASA_model_name = 'VASA_xy_10222024'
TJ_model_path =  'D:\\Mikala\\images\\training\\TJ\\models'
TJ_model_name = 'TJ_xy_10222024'

# %% [markdown]
# ## Process singe folder

# %%
fileList = pt.readFolder(INPUT_FOLDER)

print('Preparing output directory:' )
preprocDatasetFolder = pt.buildOutputFolder(PREPROCESSED_FOLDER, fileList[0].split('_')[0]+'_test')

fullPathFileList = [INPUT_FOLDER  + '\\' + f for f in fileList ]

print('Preprocessing started' )
pt.processFiles(fullPathFileList, preprocDatasetFolder, targetPxSize, channelMapping)


print('Initializing cellpose:')
pt.initializeCellPose()

print('Running cellpose segmentation')
VASA_outputFolder = pt.processVASA(preprocDatasetFolder, OUTPUT_FOLDER, VASA_model_path, VASA_model_name)
TJ_outputFolder = pt.processTJ(preprocDatasetFolder, OUTPUT_FOLDER, TJ_model_path, TJ_model_name)


print('Processing finished')



VASAstats = pt.processSegmentationMasks(VASA_outputFolder, 'VASA')
TJstats = pt.processSegmentationMasks(TJ_outputFolder, 'TJ')

exportdata = pt.mergeSegmentationResults(TJstats, VASAstats)
pt.exportSegmentationResults(exportdata, OUTPUT_FOLDER, fileList[0].split('_')[0])
# Out:
# Preprocessing files from directory: D:\Mikala\images\raw\10252024\
# 8 files found:
# 	10252024_control_ovary1_dapi_488_568_647_63x-Airyscan Processing-01.czi
# 	10252024_control_ovary2_dapi_488_568_647_63x-Airyscan Processing-02.czi
# 	10252024_control_ovary3_dapi_488_568_647_63x-Airyscan Processing-03.czi
# 	10252024_control_ovary4_dapi_488_568_647_63x-Airyscan Processing-04.czi
# 	10252024_control_ovary5_dapi_488_568_647_63x-Airyscan Processing-05.czi
# 	10252024_EGFRCA_ovary1_dapi_488_568_647_63x-Airyscan Processing-06.czi
# 	10252024_EGFRCA_ovary2_dapi_488_568_647_63x-Airyscan Processing-07.czi
# 	10252024_EGFRCA_ovary3_dapi_488_568_647_63x-Airyscan Processing-08.czi
# Preparing output directory:
# 	[buildOutputFolder] Creating:D:\Mikala\images\preproc
# 	[buildOutputFolder] Creating D:\Mikala\images\preproc\10252024_test\ch1
# 	[buildOutputFolder] Creating D:\Mikala\images\preproc\10252024_test\ch2
# 	[buildOutputFolder] Creating D:\Mikala\images\preproc\10252024_test\ch3
# 	[buildOutputFolder] Creating D:\Mikala\images\preproc\10252024_test\ch4
# Preprocessing started
# [processFiles] processing file 1 of 8
# 	Processing channel 4(VASA) as channel 1
# 		Resizing image from [954, 890, 257] to [481 449 257]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch1\10252024_control_ovary1_dapi_488_568_647_ch1_downs.tiff
# 	Processing channel 3(membrane) as channel 2
# 		Resizing image from [954, 890, 257] to [481 449 257]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch2\10252024_control_ovary1_dapi_488_568_647_ch2_downs.tiff
# 	Processing channel 2(TJ) as channel 3
# 		Resizing image from [954, 890, 257] to [481 449 257]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch3\10252024_control_ovary1_dapi_488_568_647_ch3_downs.tiff
# 	Processing channel 1(DAPI) as channel 4
# 		Resizing image from [954, 890, 257] to [481 449 257]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch4\10252024_control_ovary1_dapi_488_568_647_ch4_downs.tiff
# [processFiles] processing file 2 of 8
# 	Processing channel 4(VASA) as channel 1
# 		Resizing image from [859, 859, 214] to [433 433 214]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch1\10252024_control_ovary2_dapi_488_568_647_ch1_downs.tiff
# 	Processing channel 3(membrane) as channel 2
# 		Resizing image from [859, 859, 214] to [433 433 214]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch2\10252024_control_ovary2_dapi_488_568_647_ch2_downs.tiff
# 	Processing channel 2(TJ) as channel 3
# 		Resizing image from [859, 859, 214] to [433 433 214]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch3\10252024_control_ovary2_dapi_488_568_647_ch3_downs.tiff
# 	Processing channel 1(DAPI) as channel 4
# 		Resizing image from [859, 859, 214] to [433 433 214]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch4\10252024_control_ovary2_dapi_488_568_647_ch4_downs.tiff
# [processFiles] processing file 3 of 8
# 	Processing channel 4(VASA) as channel 1
# 		Resizing image from [859, 859, 199] to [433 433 199]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch1\10252024_control_ovary3_dapi_488_568_647_ch1_downs.tiff
# 	Processing channel 3(membrane) as channel 2
# 		Resizing image from [859, 859, 199] to [433 433 199]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch2\10252024_control_ovary3_dapi_488_568_647_ch2_downs.tiff
# 	Processing channel 2(TJ) as channel 3
# 		Resizing image from [859, 859, 199] to [433 433 199]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch3\10252024_control_ovary3_dapi_488_568_647_ch3_downs.tiff
# 	Processing channel 1(DAPI) as channel 4
# 		Resizing image from [859, 859, 199] to [433 433 199]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch4\10252024_control_ovary3_dapi_488_568_647_ch4_downs.tiff
# [processFiles] processing file 4 of 8
# 	Processing channel 4(VASA) as channel 1
# 		Resizing image from [859, 859, 230] to [433 433 230]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch1\10252024_control_ovary4_dapi_488_568_647_ch1_downs.tiff
# 	Processing channel 3(membrane) as channel 2
# 		Resizing image from [859, 859, 230] to [433 433 230]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch2\10252024_control_ovary4_dapi_488_568_647_ch2_downs.tiff
# 	Processing channel 2(TJ) as channel 3
# 		Resizing image from [859, 859, 230] to [433 433 230]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch3\10252024_control_ovary4_dapi_488_568_647_ch3_downs.tiff
# 	Processing channel 1(DAPI) as channel 4
# 		Resizing image from [859, 859, 230] to [433 433 230]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch4\10252024_control_ovary4_dapi_488_568_647_ch4_downs.tiff
# [processFiles] processing file 5 of 8
# 	Processing channel 4(VASA) as channel 1
# 		Resizing image from [885, 885, 221] to [446 446 221]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch1\10252024_control_ovary5_dapi_488_568_647_ch1_downs.tiff
# 	Processing channel 3(membrane) as channel 2
# 		Resizing image from [885, 885, 221] to [446 446 221]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch2\10252024_control_ovary5_dapi_488_568_647_ch2_downs.tiff
# 	Processing channel 2(TJ) as channel 3
# 		Resizing image from [885, 885, 221] to [446 446 221]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch3\10252024_control_ovary5_dapi_488_568_647_ch3_downs.tiff
# 	Processing channel 1(DAPI) as channel 4
# 		Resizing image from [885, 885, 221] to [446 446 221]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch4\10252024_control_ovary5_dapi_488_568_647_ch4_downs.tiff
# [processFiles] processing file 6 of 8
# 	Processing channel 4(VASA) as channel 1
# 		Resizing image from [778, 778, 195] to [392 392 195]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch1\10252024_EGFRCA_ovary1_dapi_488_568_647_ch1_downs.tiff
# 	Processing channel 3(membrane) as channel 2
# 		Resizing image from [778, 778, 195] to [392 392 195]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch2\10252024_EGFRCA_ovary1_dapi_488_568_647_ch2_downs.tiff
# 	Processing channel 2(TJ) as channel 3
# 		Resizing image from [778, 778, 195] to [392 392 195]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch3\10252024_EGFRCA_ovary1_dapi_488_568_647_ch3_downs.tiff
# 	Processing channel 1(DAPI) as channel 4
# 		Resizing image from [778, 778, 195] to [392 392 195]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch4\10252024_EGFRCA_ovary1_dapi_488_568_647_ch4_downs.tiff
# [processFiles] processing file 7 of 8
# 	Processing channel 4(VASA) as channel 1
# 		Resizing image from [843, 843, 246] to [425 425 246]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch1\10252024_EGFRCA_ovary2_dapi_488_568_647_ch1_downs.tiff
# 	Processing channel 3(membrane) as channel 2
# 		Resizing image from [843, 843, 246] to [425 425 246]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch2\10252024_EGFRCA_ovary2_dapi_488_568_647_ch2_downs.tiff
# 	Processing channel 2(TJ) as channel 3
# 		Resizing image from [843, 843, 246] to [425 425 246]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch3\10252024_EGFRCA_ovary2_dapi_488_568_647_ch3_downs.tiff
# 	Processing channel 1(DAPI) as channel 4
# 		Resizing image from [843, 843, 246] to [425 425 246]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch4\10252024_EGFRCA_ovary2_dapi_488_568_647_ch4_downs.tiff
# [processFiles] processing file 8 of 8
# 	Processing channel 4(VASA) as channel 1
# 		Resizing image from [1019, 1019, 246] to [514 514 246]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch1\10252024_EGFRCA_ovary3_dapi_488_568_647_ch1_downs.tiff
# 	Processing channel 3(membrane) as channel 2
# 		Resizing image from [1019, 1019, 246] to [514 514 246]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch2\10252024_EGFRCA_ovary3_dapi_488_568_647_ch2_downs.tiff
# 	Processing channel 2(TJ) as channel 3
# 		Resizing image from [1019, 1019, 246] to [514 514 246]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch3\10252024_EGFRCA_ovary3_dapi_488_568_647_ch3_downs.tiff
# 	Processing channel 1(DAPI) as channel 4
# 		Resizing image from [1019, 1019, 246] to [514 514 246]
# 		Saving resized file as D:\Mikala\images\preproc\10252024_test\ch4\10252024_EGFRCA_ovary3_dapi_488_568_647_ch4_downs.tiff
# Initializing cellpose:
# >>> GPU activated? YES
# Running cellpose segmentation
# Processing VASA channel:
# Cellpose model path = D:\Mikala\images\training\VASA\models\VASA_xy_10222024
# Processing file 1 of 8
# Performing prediction on: D:/Mikala/output/new_models\VASA_ch1\10252024\10252024_control_ovary1_dapi_488_568_647_ch1_downs.tiff
# 100%|██████████| 256/256 [00:01<00:00, 232.25it/s]
# Saving output files to directory:D:/Mikala/output/new_models\VASA_ch1\10252024
# Processing file 2 of 8
# Performing prediction on: D:/Mikala/output/new_models\VASA_ch1\10252024\10252024_control_ovary2_dapi_488_568_647_ch1_downs.tiff
# 25-Oct-24 16:59:28 - cellpose.dynamics - WARNING  - WARNING: no mask pixels found
# 100%|██████████| 213/213 [00:00<00:00, 804.30it/s]
# Saving output files to directory:D:/Mikala/output/new_models\VASA_ch1\10252024
# Processing file 3 of 8
# Performing prediction on: D:/Mikala/output/new_models\VASA_ch1\10252024\10252024_control_ovary3_dapi_488_568_647_ch1_downs.tiff
# 100%|██████████| 198/198 [00:00<00:00, 756.67it/s]
# Saving output files to directory:D:/Mikala/output/new_models\VASA_ch1\10252024
# Processing file 4 of 8
# Performing prediction on: D:/Mikala/output/new_models\VASA_ch1\10252024\10252024_control_ovary4_dapi_488_568_647_ch1_downs.tiff
# 100%|██████████| 229/229 [00:00<00:00, 723.20it/s]
# Saving output files to directory:D:/Mikala/output/new_models\VASA_ch1\10252024
# Processing file 5 of 8
# Performing prediction on: D:/Mikala/output/new_models\VASA_ch1\10252024\10252024_control_ovary5_dapi_488_568_647_ch1_downs.tiff
# 100%|██████████| 220/220 [00:00<00:00, 748.21it/s]
# Saving output files to directory:D:/Mikala/output/new_models\VASA_ch1\10252024
# Processing file 6 of 8
# Performing prediction on: D:/Mikala/output/new_models\VASA_ch1\10252024\10252024_EGFRCA_ovary1_dapi_488_568_647_ch1_downs.tiff
# 100%|██████████| 194/194 [00:00<00:00, 971.77it/s]
# Saving output files to directory:D:/Mikala/output/new_models\VASA_ch1\10252024
# Processing file 7 of 8
# Performing prediction on: D:/Mikala/output/new_models\VASA_ch1\10252024\10252024_EGFRCA_ovary2_dapi_488_568_647_ch1_downs.tiff
# 100%|██████████| 245/245 [00:00<00:00, 863.48it/s]
# Saving output files to directory:D:/Mikala/output/new_models\VASA_ch1\10252024
# Processing file 8 of 8
# Performing prediction on: D:/Mikala/output/new_models\VASA_ch1\10252024\10252024_EGFRCA_ovary3_dapi_488_568_647_ch1_downs.tiff
# 100%|██████████| 245/245 [00:00<00:00, 667.75it/s]
# Saving output files to directory:D:/Mikala/output/new_models\VASA_ch1\10252024
# Processing TJ channel:
# Cellpose model path = D:\Mikala\images\training\TJ\models\TJ_xy_10222024
# Processing file 1 of 8
# Performing prediction on: D:/Mikala/output/new_models\TJ_ch3\10252024\10252024_control_ovary1_dapi_488_568_647_ch3_downs.tiff
# 25-Oct-24 17:04:34 - cellpose.dynamics - WARNING  - WARNING: no mask pixels found
# 25-Oct-24 17:04:35 - cellpose.dynamics - WARNING  - WARNING: no mask pixels found
# 25-Oct-24 17:04:35 - cellpose.dynamics - WARNING  - WARNING: no mask pixels found
# 25-Oct-24 17:04:53 - cellpose.dynamics - WARNING  - WARNING: no mask pixels found
# 25-Oct-24 17:04:53 - cellpose.dynamics - WARNING  - WARNING: no mask pixels found
# 100%|██████████| 256/256 [00:00<00:00, 730.03it/s]
# Saving output files to directory:D:/Mikala/output/new_models\TJ_ch3\10252024
# Processing file 2 of 8
# Performing prediction on: D:/Mikala/output/new_models\TJ_ch3\10252024\10252024_control_ovary2_dapi_488_568_647_ch3_downs.tiff
# 100%|██████████| 213/213 [00:00<00:00, 723.64it/s]
# Saving output files to directory:D:/Mikala/output/new_models\TJ_ch3\10252024
# Processing file 3 of 8
# Performing prediction on: D:/Mikala/output/new_models\TJ_ch3\10252024\10252024_control_ovary3_dapi_488_568_647_ch3_downs.tiff
# 100%|██████████| 198/198 [00:00<00:00, 685.51it/s]
# Saving output files to directory:D:/Mikala/output/new_models\TJ_ch3\10252024
# Processing file 4 of 8
# Performing prediction on: D:/Mikala/output/new_models\TJ_ch3\10252024\10252024_control_ovary4_dapi_488_568_647_ch3_downs.tiff
# 100%|██████████| 229/229 [00:00<00:00, 723.72it/s]
# Saving output files to directory:D:/Mikala/output/new_models\TJ_ch3\10252024
# Processing file 5 of 8
# Performing prediction on: D:/Mikala/output/new_models\TJ_ch3\10252024\10252024_control_ovary5_dapi_488_568_647_ch3_downs.tiff
# 100%|██████████| 220/220 [00:00<00:00, 648.82it/s]
# Saving output files to directory:D:/Mikala/output/new_models\TJ_ch3\10252024
# Processing file 6 of 8
# Performing prediction on: D:/Mikala/output/new_models\TJ_ch3\10252024\10252024_EGFRCA_ovary1_dapi_488_568_647_ch3_downs.tiff
# 100%|██████████| 194/194 [00:00<00:00, 776.60it/s]
# Saving output files to directory:D:/Mikala/output/new_models\TJ_ch3\10252024
# Processing file 7 of 8
# Performing prediction on: D:/Mikala/output/new_models\TJ_ch3\10252024\10252024_EGFRCA_ovary2_dapi_488_568_647_ch3_downs.tiff
# 100%|██████████| 245/245 [00:00<00:00, 773.74it/s]
# Saving output files to directory:D:/Mikala/output/new_models\TJ_ch3\10252024
# Processing file 8 of 8
# Performing prediction on: D:/Mikala/output/new_models\TJ_ch3\10252024\10252024_EGFRCA_ovary3_dapi_488_568_647_ch3_downs.tiff
# 25-Oct-24 17:12:04 - cellpose.dynamics - WARNING  - WARNING: no mask pixels found
# 100%|██████████| 245/245 [00:00<00:00, 473.87it/s]
# Saving output files to directory:D:/Mikala/output/new_models\TJ_ch3\10252024
# Processing finished

# %% [markdown]
# ## Batch process  multiple folders

# %%
INPUT_FOLDER_LIST = os.listdir(INPUT_FOLDER)

for idx, FOLDER in enumerate(INPUT_FOLDER_LIST):
    TARGET_FOLDER = os.path.join(INPUT_FOLDER,FOLDER)
    print('[MAIN] processing folder ' + str(idx+1) + ' of ' +str(len(INPUT_FOLDER_LIST)))
    if not os.path.isdir(TARGET_FOLDER):
        continue

    fileList = pt.readFolder(TARGET_FOLDER)

    print('Preparing output directory:' )
    preprocDatasetFolder = pt.buildOutputFolder(PREPROCESSED_FOLDER, fileList[0].split('_')[0]+'_test')

    fullPathFileList = [TARGET_FOLDER  + '\\' + f for f in fileList ]

    print('Preprocessing started' )
    pt.processFiles(fullPathFileList, preprocDatasetFolder, targetPxSize, channelMapping)


    print('Initializing cellpose:')
    pt.initializeCellPose()

    print('Running cellpose segmentation')
    VASA_outputFolder = pt.processVASA(preprocDatasetFolder, OUTPUT_FOLDER, VASA_model_path, VASA_model_name)
    TJ_outputFolder = pt.processTJ(preprocDatasetFolder, OUTPUT_FOLDER, TJ_model_path, TJ_model_name)


    print('Processing finished')


    VASAstats = pt.processSegmentationMasks(VASA_outputFolder, 'VASA')
    TJstats = pt.processSegmentationMasks(TJ_outputFolder, 'TJ')

    exportdata = pt.mergeSegmentationResults(TJstats, VASAstats)
    pt.exportSegmentationResults(exportdata, OUTPUT_FOLDER, fileList[0].split('_')[0])
