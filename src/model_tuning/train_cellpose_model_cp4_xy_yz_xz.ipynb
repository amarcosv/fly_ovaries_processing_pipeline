# %%
#import numpy as np
import time, os, sys
import shutil
from tifffile import imwrite
from skimage import img_as_float32
#from urllib.parse import urlparse
import matplotlib.pyplot as plt
import matplotlib as mpl
import skimage
from sklearn.model_selection import train_test_split
#%matplotlib inline
mpl.rcParams['figure.dpi'] = 300
from cellpose import core, utils, io, models, metrics, train, transforms

use_GPU = core.use_gpu()
yn = ['NO', 'YES']
print(f'>>> GPU activated? {yn[use_GPU]}')

core.assign_device(use_torch=True, gpu=True, device=0)

import torch


epoch = 200
lrate = 0.00001
wdecay = 0.1
# Out:
# Welcome to CellposeSAM, cellpose v
# cellpose version: 	4.0.6
# platform:       	win32
# python version: 	3.10.16
# torch version:  	2.6.0+cu126! The neural network component of
# CPSAM is much larger than in previous versions and CPU excution is slow.
# We encourage users to use GPU/MPS if available.
#
#
# >>> GPU activated? YES

# %%
training_path = "D:\\Mikala\\images\\training\\TJ"
model_path = "D:\\Mikala\\images\\training" + "\\models\\cp4\\"

modelName = 'TJ_xy_07292025'

#images = io
# list to store files
annotation_files = []
# Iterate directory
for file in os.listdir(training_path):
    # check only text files
    if file.endswith('.npy'):
        annotation_files.append(file)
#print(annotation_files)

image_files = [os.path.join(training_path,sub.replace('_seg.npy', '.tif')) for sub in annotation_files]
annotation_files = [os.path.join(training_path,sub) for sub in annotation_files]
print(image_files)
print(annotation_files)

images_train, images_test, masks_train, masks_test = train_test_split(image_files, annotation_files, test_size=0.1, random_state=42)
print(images_train)
print(masks_train)
print(images_test)
print(masks_test)
# Out:
# ['D:\\Mikala\\images\\training\\TJ\\08172024_A_ovary2_dapi_488_582_647_ch3_downs_xy_0.tif', 'D:\\Mikala\\images\\training\\TJ\\08172024_A_ovary2_dapi_488_582_647_ch3_downs_xy_3.tif', 'D:\\Mikala\\images\\training\\TJ\\08172024_A_ovary2_dapi_488_582_647_ch3_downs_xy_4.tif', 'D:\\Mikala\\images\\training\\TJ\\08172024_A_ovary4_dapi_488_582_647_ch3_downs_xy_0.tif', 'D:\\Mikala\\images\\training\\TJ\\08172024_A_ovary4_dapi_488_582_647_ch3_downs_xy_1.tif', 'D:\\Mikala\\images\\training\\TJ\\08172024_A_ovary4_dapi_488_582_647_ch3_downs_xy_3.tif', 'D:\\Mikala\\images\\training\\TJ\\08172024_A_ovary4_dapi_488_582_647_ch3_downs_xy_4.tif', 'D:\\Mikala\\images\\training\\TJ\\08172024_B_ovary2_dapi_488_582_647_ch3_downs_xy_0.tif', 'D:\\Mikala\\images\\training\\TJ\\08172024_B_ovary2_dapi_488_582_647_ch3_downs_xy_1.tif', 'D:\\Mikala\\images\\training\\TJ\\08172024_B_ovary2_dapi_488_582_647_ch3_downs_xy_2.tif', 'D:\\Mikala\\images\\training\\TJ\\08172024_B_ovary2_dapi_488_582_647_ch3_downs_xy_3.tif', 'D:\\Mikala\\images\\training\\TJ\\08172024_B_ovary2_dapi_488_582_647_ch3_downs_xy_4.tif', 'D:\\Mikala\\images\\training\\TJ\\08172024_B_ovary5_dapi_488_582_647_ch3_downs_xy_0.tif', 'D:\\Mikala\\images\\training\\TJ\\08172024_B_ovary5_dapi_488_582_647_ch3_downs_xy_1.tif', 'D:\\Mikala\\images\\training\\TJ\\08172024_B_ovary5_dapi_488_582_647_ch3_downs_xy_2.tif', 'D:\\Mikala\\images\\training\\TJ\\08172024_B_ovary5_dapi_488_582_647_ch3_downs_xy_3.tif', 'D:\\Mikala\\images\\training\\TJ\\08172024_B_ovary5_dapi_488_582_647_ch3_downs_xy_4.tif', 'D:\\Mikala\\images\\training\\TJ\\08312024_A_ovary1_squished_ch3_downs_xy_3.tif', 'D:\\Mikala\\images\\training\\TJ\\08312024_A_ovary8_ch3_downs_xy_2.tif', 'D:\\Mikala\\images\\training\\TJ\\08312024_A_ovary8_ch3_downs_xy_3.tif', 'D:\\Mikala\\images\\training\\TJ\\08312024_B_ovary2_ch3_downs_xy_1.tif', 'D:\\Mikala\\images\\training\\TJ\\08312024_B_ovary2_ch3_downs_xy_2.tif', 'D:\\Mikala\\images\\training\\TJ\\08312024_B_ovary2_ch3_downs_xy_3.tif', 'D:\\Mikala\\images\\training\\TJ\\08312024_B_ovary2_ch3_downs_xy_4.tif', 'D:\\Mikala\\images\\training\\TJ\\08312024_B_ovary5_ch3_downs_xy_0.tif', 'D:\\Mikala\\images\\training\\TJ\\08312024_B_ovary5_ch3_downs_xy_1.tif', 'D:\\Mikala\\images\\training\\TJ\\08312024_B_ovary5_ch3_downs_xy_3.tif', 'D:\\Mikala\\images\\training\\TJ\\08312024_B_ovary5_ch3_downs_xy_4.tif', 'D:\\Mikala\\images\\training\\TJ\\09012024_A_ovary2_ch3_downs_xy_0.tif', 'D:\\Mikala\\images\\training\\TJ\\09012024_A_ovary2_ch3_downs_xy_1.tif', 'D:\\Mikala\\images\\training\\TJ\\09012024_A_ovary2_ch3_downs_xy_2.tif', 'D:\\Mikala\\images\\training\\TJ\\09012024_A_ovary2_ch3_downs_xy_3.tif', 'D:\\Mikala\\images\\training\\TJ\\09012024_A_ovary5_ch3_downs_xy_3.tif', 'D:\\Mikala\\images\\training\\TJ\
seg.npy', 'D:\\Mikala\\images\\training\\TJ\\08312024_A_ovary8_ch3_downs_xy_2_seg.npy', 'D:\\Mikala\\images\\training\\TJ\\08172024_B_ovary2_dapi_488_582_647_ch3_downs_xy_3_seg.npy']

# %% [markdown]
# ## training TJ

# %%
model = models.CellposeModel(model_type="nuclei", gpu=True)
from tqdm import trange
io.logger_setup()



normalize_custom_training = {
    "lowhigh": [0,255],
    "percentile": None,
    "normalize": True,
    "norm3D": False,
    "sharpen_radius": 0,
    "smooth_radius": 0,
    "tile_norm_blocksize": 0,
    "tile_norm_smooth3D": 1,
    "invert": False
}



model_path = train.train_seg(model.net, 
                            train_files=images_train, train_labels_files=masks_train,
                            normalize=True, channels=[0,0], compute_flows=False,
                            test_files=images_test, test_labels_files=masks_test,
                            weight_decay=wdecay, SGD=True, learning_rate=lrate,
                            n_epochs=epoch, 
                            save_path= model_path, model_name=modelName)




# cellpose.train.train_seg(net, train_data=None, train_labels=None, train_files=None, train_labels_files=None, train_probs=None, test_data=None, test_labels=None,
#                           test_files=None, test_labels_files=None, test_probs=None, load_files=True, batch_size=8, learning_rate=0.005, n_epochs=2000,
#                          weight_decay=1e-05, momentum=0.9, SGD=False, channels=None, channel_axis=None, rgb=False, normalize=True, compute_flows=False,
#                            save_path=None, save_every=100, nimg_per_epoch=None, nimg_test_per_epoch=None, rescale=True, scale_range=None, 
#                          bsize=224, min_train_masks=5, model_name=None)
# Out:
# 2024-10-22 02:09:23,687 [INFO] >> nuclei << model set to be used
# 2024-10-22 02:09:23,687 [INFO] ** TORCH CUDA version installed and working. **
# 2024-10-22 02:09:23,687 [INFO] >>>> using GPU
# 2024-10-22 02:09:23,773 [INFO] >>>> loading model C:\Users\amarcosv\.cellpose\models\nucleitorch_0
# 2024-10-22 02:09:23,901 [INFO] >>>> model diam_mean =  17.000 (ROIs rescaled to this size during training)
# creating new log file
# 2024-10-22 02:09:23,902 [INFO] WRITING LOG OUTPUT TO C:\Users\amarcosv\.cellpose\run.log
# 2024-10-22 02:09:23,903 [INFO]
# cellpose version: 	3.0.10
# platform:       	win32
# python version: 	3.10.14
# torch version:  	2.2.2
# 2024-10-22 02:09:23,905 [INFO] >>> loading images and labels
# 62
# 100%|██████████| 62/62 [00:00<00:00, 550.95it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 21
#       3 io.logger_setup()
#       7 normalize_custom_training = {
#       8     "lowhigh": [0,255],
#       9     "percentile": None,
#    (...)
#      16     "invert": False
#      17 }
# ---> 21 model_path = train.train_seg(model.net,
#      22                             train_files=images_train, train_labels_files=masks_train,
#      23                             normalize=True, channels=[0,0], compute_flows=False,
#      24                             test_files=images_test, test_labels_files=masks_test,
#      25                             weight_decay=wdecay, SGD=True, learning_rate=lrate,
#      26                             n_epochs=epoch,
#      27                             save_path= model_path, model_name=modelName)
#      32 # cellpose.train.train_seg(net, train_data=None, train_labels=None, train_files=None, train_labels_files=None, train_probs=None, test_data=None, test_labels=None,
#      33 #                           test_files=None, test_labels_files=None, test_probs=None, load_files=True, batch_size=8, learning_rate=0.005, n_epochs=2000,
#      34 #                          weight_decay=1e-05, momentum=0.9, SGD=False, channels=None, channel_axis=None, rgb=False, normalize=True, compute_flows=False,
#      35 #                            save_path=None, save_every=100, nimg_per_epoch=None, nimg_test_per_epoch=None, rescale=True, scale_range=None,
#      36 #                          bsize=224, min_train_masks=5, model_name=None)
#
# File c:\Users\mcapage1\AppData\Local\mambaforge\envs\mikala_processing\lib\site-packages\cellpose\train.py:385, in train_seg(net, train_data, train_labels, train_files, train_labels_files, train_probs, test_data, test_labels, test_files, test_labels_files, test_probs, load_files, batch_size, learning_rate, n_epochs, weight_decay, momentum, SGD, channels, channel_axis, rgb, normalize, compute_flows, save_path, save_every, nimg_per_epoch, nimg_test_per_epoch, rescale, scale_range, bsize, min_train_masks, model_name)
#     382     normalize_params = models.normalize_default
#     383     normalize_params["normalize"] = normalize
# --> 385 out = _process_train_test(train_data=train_data, train_labels=train_labels,
#     386                           train_files=train_files, train_probs=train_probs,
#     387                           test_data=test_data, test_labels=test_labels,
#     388                           test_files=test_files, test_probs=test_probs,
#     389                           load_files=load_files, min_train_masks=min_train_masks,
#     390                           compute_flows=compute_flows, channels=channels,
#     391                           channel_axis=channel_axis, rgb=rgb,
#     392                           normalize_params=normalize_params, device=net.device)
#     393 (train_data, train_labels, train_files, train_labels_files, train_probs, diam_train,
#     394  test_data, test_labels, test_files, test_labels_files, test_probs, diam_test,
#     395  normed) = out
#     396 # already normalized, do not normalize during training
#
# File c:\Users\mcapage1\AppData\Local\mambaforge\envs\mikala_processing\lib\site-packages\cellpose\train.py:211, in _process_train_test(train_data, train_labels, train_files, train_labels_files, train_probs, test_data, test_labels, test_files, test_labels_files, test_probs, load_files, min_train_masks, compute_flows, channels, channel_axis, rgb, normalize_params, device)
#     209     print(nimg)
#     210     train_data = [io.imread(train_files[i]) for i in trange(nimg)]
# --> 211     train_labels = [io.imread(train_labels_files[i]) for i in trange(nimg)]
#     212 nimg_test = len(test_files) if test_files is not None else None
#     213 if load_files and nimg_test:
#
# File c:\Users\mcapage1\AppData\Local\mambaforge\envs\mikala_processing\lib\site-packages\cellpose\train.py:211, in <listcomp>(.0)
#     209     print(nimg)
#     210     train_data = [io.imread(train_files[i]) for i in trange(nimg)]
# --> 211     train_labels = [io.imread(train_labels_files[i]) for i in trange(nimg)]
#     212 nimg_test = len(test_files) if test_files is not None else None
#     213 if load_files and nimg_test:
#
# IndexError: list index out of range

# %%
training_path = "D:\\Mikala\\images\\training\\VASA\\VASA_training_datasets_2025\\train"
model_path = "D:\\Mikala\\images\\training\\VASA\\VASA_training_datasets_2025" #+ "\\models\\"

modelName = 'VASA_082025set_cp4_xy_yz_xz_08072025_300epoch'

#images = io
# list to store files
annotation_files = []
# Iterate directory
for file in os.listdir(training_path):
    # check only text files
    if file.endswith('.npy'):
        annotation_files.append(file)
#print(annotation_files)

image_files = [os.path.join(training_path,sub.replace('_seg.npy', '.tif')) for sub in annotation_files]
annotation_files = [os.path.join(training_path,sub) for sub in annotation_files]
print(image_files)
print(annotation_files)

images_train, images_test, masks_train, masks_test = train_test_split(image_files, annotation_files, test_size=0.2, random_state=42)
print(images_train)
print(masks_train)
print(images_test)
print(masks_test)
# Out:
# ['D:\\Mikala\\images\\training\\VASA\\VASA_training_datasets_2025\\train\\01202025_cora_dapi_488_555_647_ovary8_ch1_downs_YX_0.tif', 'D:\\Mikala\\images\\training\\VASA\\VASA_training_datasets_2025\\train\\01202025_cora_dapi_488_555_647_ovary8_ch1_downs_YX_1.tif', 'D:\\Mikala\\images\\training\\VASA\\VASA_training_datasets_2025\\train\\01202025_cora_dapi_488_555_647_ovary8_ch1_downs_YX_2.tif', 'D:\\Mikala\\images\\training\\VASA\\VASA_training_datasets_2025\\train\\01202025_cora_dapi_488_555_647_ovary8_ch1_downs_YX_3.tif', 'D:\\Mikala\\images\\training\\VASA\\VASA_training_datasets_2025\\train\\01202025_cora_dapi_488_555_647_ovary8_ch1_downs_YX_4.tif', 'D:\\Mikala\\images\\training\\VASA\\VASA_training_datasets_2025\\train\\01202025_cora_dapi_488_555_647_ovary8_ch1_downs_YX_6.tif', 'D:\\Mikala\\images\\training\\VASA\\VASA_training_datasets_2025\\train\\01202025_cora_dapi_488_555_647_ovary8_ch1_downs_YX_7.tif', 'D:\\Mikala\\images\\training\\VASA\\VASA_training_datasets_2025\\train\\01202025_cora_dapi_488_555_647_ovary8_ch1_downs_YX_8.tif', 'D:\\Mikala\\images\\training\\VASA\\VASA_training_datasets_2025\\train\\01202025_cora_dapi_488_555_647_ovary8_ch1_downs_YX_9.tif', 'D:\\Mikala\\images\\training\\VASA\\VASA_training_datasets_2025\\train\\01202025_cora_dapi_488_555_647_ovary8_ch1_downs_ZX_0.tif', 'D:\\Mikala\\images\\training\\VASA\\VASA_training_datasets_2025\\train\\01202025_cora_dapi_488_555_647_ovary8_ch1_downs_ZX_1.tif', 'D:\\Mikala\\images\\training\\VASA\\VASA_training_datasets_2025\\train\\01202025_cora_dapi_488_555_647_ovary8_ch1_downs_ZX_6.tif', 'D:\\Mikala\\images\\training\\VASA\\VASA_training_datasets_2025\\train\\01202025_cora_dapi_488_555_647_ovary8_ch1_downs_ZX_8.tif', 'D:\\Mikala\\images\\training\\VASA\\VASA_training_datasets_2025\\train\\01202025_cora_dapi_488_555_647_ovary8_ch1_downs_ZX_9.tif', 'D:\\Mikala\\images\\training\\VASA\\VASA_training_datasets_2025\\train\\01202025_cora_dapi_488_555_647_ovary8_ch1_downs_ZY_1.tif', 'D:\\Mikala\\images\\training\\VASA\\VASA_training_datasets_2025\\train\\01202025_cora_dapi_488_555_647_ovary8_ch1_downs_ZY_2.tif', 'D:\\Mikala\\images\\training\\VASA\\VASA_training_datasets_2025\\train\\01202025_cora_dapi_488_555_647_ovary8_ch1_downs_ZY_3.tif', 'D:\\Mikala\\images\\training\\VASA\\VASA_training_datasets_2025\\train\\01202025_cora_dapi_488_555_647_ovary8_ch1_downs_ZY_9.tif', 'D:\\Mikala\\images\\training\\VASA\\VASA_training_datasets_2025\\train\\02222025_control_dapi_488_555_647_ovary4_ch1_downs_YX_0.tif', 'D:\\Mikala\\images\\training\\VASA\\VASA_training_datasets_2025\\train\\02222025_control_dapi_488_555_647_ovary4_ch1_downs_YX_1.tif', 'D:\\Mikala\\images\\training\\VASA\\VASA_training_datasets_2025\\train\\02222025_control_dapi_488_555_647_ovary4_ch1_downs_YX_2.tif', 'D:\\Mikala\\images\\training\\VASA\\VASA_training_datasets_2025\\train\\02222025_control_dapi_488_555_647_ovary4_ch1_downs_YX_3.tif', 'D:\\Mikala\\images\\training\\VASA\\VASA_training_datasets_2025\\train\\02222025_control_dapi_488_555_647_ovary4_ch1_downs_YX_4.tif', 'D:\\Mikala\\images\\training\\VASA\\VASA_training_datasets_2025\\train\\02222025_control_dapi_488_555_647_ovary4_ch1_downs_YX_5.tif', 'D:\\Mikala\\images\\training\\VASA\\VASA_training_datasets_2025\\train\\02222025_control_dapi_488_555_647_ovary4_ch1_downs_YX_6.tif', 'D:\\Mikala\\images\\training\\VASA\\VASA_training_datasets_2025\\train\\02222025_control_dapi_488_555_647_ovary4_ch1_downs_YX_7.tif', 'D:\\Mikala\\images\\training\\VASA\\VASA_training_datasets_2025\\train\\02222025_control_dapi_488_555_647_ovary4_ch1_downs_YX_8.tif', 'D:\\Mikala\\images\\training\\VASA\\VASA_training_datasets_2025\\train\\02222025_control_dapi_488_555_647_ovary4_ch1_downs_YX
                            test_files=images_test, test_labels_files=masks_test,
                            weight_decay=wdecay, learning_rate=lrate,
                            n_epochs=epoch, 
                            save_path= model_path, model_name=modelName, min_train_masks = 1, batch_size = Batch_size)


#Print training loss
train_loss = model_path[1]
test_loss = model_path[2]
#train_loss = train_loss[test_loss != 0]
test_loss = test_loss[test_loss != 0]
epochs = np.linspace(0, epoch, num=int(epoch/5))

# Create a figure and a set of axes
fig = plt.figure(figsize=(6, 4))
# Plot the two curves on the same axes
plt.plot(range(epoch), train_loss, label='Train Loss', linestyle='-', marker='o')
plt.plot(epochs, test_loss, label='Test Loss', linestyle='--', marker='x')

# Add labels, title, and legend
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.legend()

# Display the plot
plt.show()

# cellpose.train.train_seg(net, train_data=None, train_labels=None, train_files=None, train_labels_files=None, train_probs=None, test_data=None, test_labels=None,
#                           test_files=None, test_labels_files=None, test_probs=None, load_files=True, batch_size=8, learning_rate=0.005, n_epochs=2000,
#                          weight_decay=1e-05, momentum=0.9, SGD=False, channels=None, channel_axis=None, rgb=False, normalize=True, compute_flows=False,
#                            save_path=None, save_every=100, nimg_per_epoch=None, nimg_test_per_epoch=None, rescale=True, scale_range=None, 
#                          bsize=224, min_train_masks=5, model_name=None)
# Out:
# creating new log file
# 2025-08-07 17:16:07,983 [INFO] WRITING LOG OUTPUT TO C:\Users\amarcosv\.cellpose\run.log
# 2025-08-07 17:16:07,999 [INFO]
# cellpose version: 	4.0.6
# platform:       	win32
# python version: 	3.10.16
# torch version:  	2.6.0+cu126
# 2025-08-07 17:16:07,999 [INFO] >>> loading images and labels
# 100%|██████████| 212/212 [00:00<00:00, 282.66it/s]
# 100%|██████████| 212/212 [00:00<00:00, 531.34it/s]
# 100%|██████████| 53/53 [00:00<00:00, 289.45it/s]
# 100%|██████████| 53/53 [00:00<00:00, 527.77it/s]
# 2025-08-07 17:16:09,434 [INFO] computing flows for labels
# 100%|██████████| 212/212 [00:16<00:00, 13.19it/s]
# 2025-08-07 17:16:25,592 [INFO] computing flows for labels
# 100%|██████████| 53/53 [00:04<00:00, 12.82it/s]
# 2025-08-07 17:16:29,760 [INFO] >>> computing diameters
# 100%|██████████| 212/212 [00:00<00:00, 1148.85it/s]
# 100%|██████████| 53/53 [00:00<00:00, 1009.35it/s]
# 2025-08-07 17:16:30,016 [INFO] >>> n_epochs=300, n_train=212, n_test=53
# 2025-08-07 17:16:30,017 [INFO] >>> AdamW, learning_rate=0.00001, weight_decay=0.10000
# 2025-08-07 17:16:30,019 [INFO] >>> saving model to D:\Mikala\images\training\VASA\VASA_training_datasets_2025\models\VASA_082025set_cp4_xy_yz_xz_08072025_300epoch
# 2025-08-07 17:17:23,586 [INFO] 0, train_loss=0.4001, test_loss=0.4309, LR=0.000000, time 53.57s
# 2025-08-07 17:21:42,025 [INFO] 5, train_loss=0.3604, test_loss=0.3265, LR=0.000006, time 312.01s
# 2025-08-07 17:26:01,665 [INFO] 10, train_loss=0.2749, test_loss=0.2433, LR=0.000010, time 571.65s
# 2025-08-07 17:34:39,027 [INFO] 20, train_loss=0.2375, test_loss=0.2199, LR=0.000010, time 1089.01s
# 2025-08-07 17:43:17,522 [INFO] 30, train_loss=0.2240, test_loss=0.2143, LR=0.000010, time 1607.50s
# 2025-08-07 17:51:56,885 [INFO] 40, train_loss=0.2221, test_loss=0.2114, LR=0.000010, time 2126.87s
# 2025-08-07 18:00:35,330 [INFO] 50, train_loss=0.2186, test_loss=0.2095, LR=0.000010, time 2645.31s
# 2025-08-07 18:09:14,693 [INFO] 60, train_loss=0.2116, test_loss=0.2080, LR=0.000010, time 3164.68s
# 2025-08-07 18:17:54,172 [INFO] 70, train_loss=0.2114, test_loss=0.2071, LR=0.000010, time 3684.15s
# 2025-08-07 18:26:32,384 [INFO] 80, train_loss=0.2137, test_loss=0.2063, LR=0.000010, time 4202.37s
# 2025-08-07 18:35:12,314 [INFO] 90, train_loss=0.2105, test_loss=0.2051, LR=0.000010, time 4722.30s
# 2025-08-07 18:43:50,759 [INFO] 100, train_loss=0.2093, test_loss=0.2049, LR=0.000010, time 5240.74s
# 2025-08-07 18:43:50,759 [INFO] saving network parameters to D:\Mikala\images\training\VASA\VASA_training_datasets_2025\models\VASA_082025set_cp4_xy_yz_xz_08072025_300epoch
# 2025-08-07 18:52:47,080 [INFO] 110, train_loss=0.2155, test_loss=0.2045, LR=0.000010, time 5777.06s
# 2025-08-07 19:01:25,542 [INFO] 120, train_loss=0.2089, test_loss=0.2034, LR=0.000010, time 6295.52s
# 2025-08-07 19:10:05,838 [INFO] 130, train_loss=0.2063, test_loss=0.2033, LR=0.000010, time 6815.82s
# 2025-08-07 19:18:44,740 [INFO] 140, train_loss=0.2094, test_loss=0.2034, LR=0.000010, time 7334.72s
# 2025-08-07 19:27:23,646 [INFO] 150, train_loss=0.2089, test_loss=0.2030, LR=0.000010, time 7853.63s
# 2025-08-07 19:36:02,275 [INFO] 160, train_loss=0.2096, test_loss=0.2029, LR=0.000010, time 8372.26s
# 2025-08-07 19:44:39,370 [INFO] 170, train_loss=0.2105, test_loss=0.2025, LR=0.000010, time 8889.35s
# 2025-08-07 19:53:19,350 [INFO] 180, train_loss=0.2057, test_loss=0.2024, LR=0.000010, time 9409.33s
# 2025-08-07 20:01:58,629 [INFO] 190, train_loss=0.2066, test_loss=0.2022, LR=0.000010, time 9928.61s
# 2025-08-07 20:10:37,078 [INFO] 200, train_loss=0.2067, test_loss=0.2021, LR=0.000010, time 10447.06s
# 2025-08-07 20:10:37,078 [INFO] saving network parameters to D:\Mikala\images\training\VASA\VASA_training_datasets_2025\models\VASA_082025set_cp4_xy_yz_xz_08072025_300epoch
# 2025-08-07 20:19:28,993 [INFO] 210, train_loss=0.2081, test_loss=0.2020, LR=0.000010, time 10978.98s
# 2025-08-07 20:28:09,522 [INFO] 220, train_loss=0.2074, test_loss=0.2020, LR=0.000010, time 11499.50s
# 2025-08-07 20:36:50,103 [INFO] 230, train_loss=0.2063, test_loss=0.2022, LR=0.000010, time 12020.09s
# 2025-08-07 20:45:28,299 [INFO] 240, train_loss=0.2034, test_loss=0.2018, LR=0.000010, time 12538.28s
# 2025-08-07 20:54:08,579 [INFO] 250, train_loss=0.2059, test_loss=0.2019, LR=0.000005, time 13058.56s
# 2025-08-07 21:02:47,424 [INFO] 260, train_loss=0.2043, test_loss=0.2018, LR=0.000001, time 13577.41s
# 2025-08-07 21:11:29,138 [INFO] 270, train_loss=0.2054, test_loss=0.2020, LR=0.000000, time 14099.12s
# 2025-08-07 21:20:07,584 [INFO] 280, train_loss=0.2078, test_loss=0.2020, LR=0.000000, time 14617.57s
# 2025-08-07 21:28:44,829 [INFO] 290, train_loss=0.2086, test_loss=0.2018, LR=0.000000, time 15134.81s
# 2025-08-07 21:36:31,053 [INFO] saving network parameters to D:\Mikala\images\training\VASA\VASA_training_datasets_2025\models\VASA_082025set_cp4_xy_yz_xz_08072025_300epoch
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 46
#      44 # Plot the two curves on the same axes
#      45 plt.plot(range(epoch), train_loss, label='Train Loss', linestyle='-', marker='o')
# ---> 46 plt.plot(epochs, test_loss, label='Test Loss', linestyle='--', marker='x')
#      48 # Add labels, title, and legend
#      49 plt.xlabel('Epoch')
#
# File c:\Users\amarcosv\Conda\envs\cellpose4\lib\site-packages\matplotlib\pyplot.py:3827, in plot(scalex, scaley, data, *args, **kwargs)
#    3819 @_copy_docstring_and_deprecators(Axes.plot)
#    3820 def plot(
#    3821     *args: float | ArrayLike | str,
#    (...)
#    3825     **kwargs,
#    3826 ) -> list[Line2D]:
# -> 3827     return gca().plot(
#    3828         *args,
#    3829         scalex=scalex,
#    3830         scaley=scaley,
#    3831         **({"data": data} if data is not None else {}),
#    3832         **kwargs,
#    3833     )
#
# File c:\Users\amarcosv\Conda\envs\cellpose4\lib\site-packages\matplotlib\axes\_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
#    1535 Plot y versus x as lines and/or markers.
#    1536
#    (...)
#    1774 (``'green'``) or hex strings (``'#008000'``).
#    1775 """
#    1776 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778 for line in lines:
#    1779     self.add_line(line)
#
# File c:\Users\amarcosv\Conda\envs\cellpose4\lib\site-packages\matplotlib\axes\_base.py:297, in _process_plot_var_args.__call__(self, axes, data, return_kwargs, *args, **kwargs)
#     295     this += args[0],
#     296     args = args[1:]
# --> 297 yield from self._plot_args(
#     298     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey,
#     299     return_kwargs=return_kwargs
#     300 )
#
# File c:\Users\amarcosv\Conda\envs\cellpose4\lib\site-packages\matplotlib\axes\_base.py:494, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     491     axes.yaxis.update_units(y)
#     493 if x.shape[0] != y.shape[0]:
# --> 494     raise ValueError(f"x and y must have same first dimension, but "
#     495                      f"have shapes {x.shape} and {y.shape}")
#     496 if x.ndim > 2 or y.ndim > 2:
#     497     raise ValueError(f"x and y can be no greater than 2D, but have "
#     498                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (60,) and (31,)

# %%
import numpy as np

train_loss = model_path[1]
test_loss = model_path[2]
train_loss = train_loss[test_loss != 0]
test_loss = test_loss[test_loss != 0]
epochs = np.linspace(0, epoch, num=int(epoch/10)+1)

# Create a figure and a set of axes
fig = plt.figure(figsize=(6, 4))
# Plot the two curves on the same axes
#plt.plot(range(epoch), train_loss, label='Train Loss', linestyle='-', marker='o')
plt.plot(epochs, train_loss, label='Train Loss', linestyle='--', marker='x')
plt.plot(epochs, test_loss, label='Test Loss', linestyle='--', marker='x')
plt.yscale('log') 
# Add labels, title, and legend
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.legend()

# Display the plot
plt.show()
