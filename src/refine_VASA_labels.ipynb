# %%
#from pylibCZIrw import czi as pyczi
#import ipywidgets as widgets
# import json
# from matplotlib import pyplot as plt
# import matplotlib.cm as cm
# import numpy as np
# import os, sys
# from tqdm import tqdm
# from tqdm.contrib import itertools as it
# from matplotlib.patches import Rectangle
# from aicsimageio import AICSImage
# from aicsimageprocessing import resize
# from aicsimageio.writers import OmeTiffWriter
# from aicsimageio.types import PhysicalPixelSizes
import processing_tools as pt
import os

# show the used python env
#print("Using:", sys.executable)
# get current directory
path = os.getcwd()
print("Current Directory", path)
 
# prints parent directory
print(os.path.abspath(os.path.join(path, os.pardir)))
# Out:
# 14-Jan-26 13:29:08 - bfio.backends - WARNING  - Java backend is not available. This could be due to a missing dependency (jpype).
# c:\Users\amarcosv\AppData\Local\miniforge3\envs\cellpose_mikala_pipeline\lib\site-packages\dask\dataframe\__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# Current Directory e:\code\Mikala\fly_ovaries_processing_pipeline\src
# e:\code\Mikala\fly_ovaries_processing_pipeline

# %%
# Use this to point to specific folders to process
INPUT_FOLDER = ['Z:\\Mikala\\cell_size_issue\\test_folders\\09122025',
                'Z:\\Mikala\\cell_size_issue\\test_folders\\09192025']
#Use this to point to a folder containing all the subfolders to batch process
# INPUT_FOLDER = 'Z:\\Mikala\\cell_size_issue\\test_folders' 

#output folder
OUTPUT_FOLDER = 'Z:\\Mikala\\cell_size_issue\\test_folders\\output' 


label = 'VASA'

# %% [markdown]
# ## Process VASA folders

# %%
if isinstance(INPUT_FOLDER, list):
     print('Running batch preprocessing on specified folders: ', INPUT_FOLDER)
     folderList = [f for f in INPUT_FOLDER if os.path.isdir(f)]

else:
    print('Running batch preprocessing on all subfolders in: ', INPUT_FOLDER)    
    folderList = [os.path.join(INPUT_FOLDER, f) for f in os.listdir(INPUT_FOLDER) if os.path.isdir(os.path.join(INPUT_FOLDER, f))]

if not os.path.exists(OUTPUT_FOLDER):
    os.makedirs(OUTPUT_FOLDER)

for folder in folderList:
    print('Processing folder: ', folder)
    basename = os.path.basename(folder)


    regionCounts, segmentedRegions = pt.processVASASegmentationMasks(folder, label)
    pt.exportVASASegmentationResults(regionCounts, OUTPUT_FOLDER, basename)
    pt.exportVASASegmentationDetailedStats(segmentedRegions, OUTPUT_FOLDER, basename)
# Out:
# Processing folder:  Z:\Mikala\cell_size_issue\test_folders\09122025
# [processVASASegmentationMasks] Found 10 outliers in file:  09122025_control_dapi_488_555_647_ovary7_ch1_downs_cp_masks.tif
# [processVASASegmentationMasks] Found 12 outliers in file:  09122025_control_dapi_488_555_647_ovary8_ch1_downs_cp_masks.tif
# [processVASASegmentationMasks] Found 11 outliers in file:  09122025_control_dapi_488_555_647_ovary9_ch1_downs_cp_masks.tif
# Processing folder:  Z:\Mikala\cell_size_issue\test_folders\09192025
# [processVASASegmentationMasks] Found 5 outliers in file:  09192025_nosControl_dapi_488_555_647_ovary1_ch1_downs_cp_masks.tif
# [processVASASegmentationMasks] Found 1 outliers in file:  09192025_nosControl_dapi_488_555_647_ovary2_ch1_downs_cp_masks.tif
# [processVASASegmentationMasks] Found 8 outliers in file:  09192025_nosControl_dapi_488_555_647_ovary3_ch1_downs_cp_masks.tif
# Processing folder:  Z:\Mikala\cell_size_issue\test_folders\output
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 14
#      10 print('Processing folder: ', folder)
#      11 basename = os.path.basename(folder)
# ---> 14 regionCounts, segmentedRegions = pt.processVASASegmentationMasks(folder, label)
#      15 pt.exportVASASegmentationResults(regionCounts, OUTPUT_FOLDER, basename)
#      16 pt.exportVASASegmentationDetailedStats(segmentedRegions, OUTPUT_FOLDER, basename)
#
# File e:\code\Mikala\fly_ovaries_processing_pipeline\src\processing_tools.py:577, in processVASASegmentationMasks(masksFolder, label, px_size)
#     569     io.imsave(os.path.join(masksFolder, maskFile.split('.tif')[0] + '_refined.tif'), refined_labeled_image.astype('uint8'), plugin='tifffile', compression='lzw')
#     571     #props = pd.DataFrame(measure.regionprops_table(mask, properties =['label', 'num_pixels']))
#     572     #props['dataset'] = maskFile.split('_ch')[0]
#     573     #props['date'] = maskFile.split('_')[0]
#     574
#     575     #= pd.concat([segmentedRegions, props],ignore_index=True)
# --> 577 regionStats = segmentedRegions.groupby(['dataset','date'],as_index=False, group_keys=False)['outlier'].count()
#     578 outliers = segmentedRegions.groupby(['dataset','date'],as_index=False, group_keys=False)['outlier'].sum()
#     579 regionStats['refined_counts'] = regionStats['outlier'] - outliers['outlier']
#
# File c:\Users\amarcosv\AppData\Local\miniforge3\envs\cellpose_mikala_pipeline\lib\site-packages\pandas\core\frame.py:9170, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9167 if level is None and by is None:
#    9168     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9170 return DataFrameGroupBy(
#    9171     obj=self,
#    9172     keys=by,
#    9173     axis=axis,
#    9174     level=level,
#    9175     as_index=as_index,
#    9176     sort=sort,
#    9177     group_keys=group_keys,
#    9178     observed=observed,
#    9179     dropna=dropna,
#    9180 )
#
# File c:\Users\amarcosv\AppData\Local\miniforge3\envs\cellpose_mikala_pipeline\lib\site-packages\pandas\core\groupby\groupby.py:1329, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1326 self.dropna = dropna
#    1328 if grouper is None:
# -> 1329     grouper, exclusions, obj = get_grouper(
#    1330         obj,
#    1331         keys,
#    1332         axis=axis,
#    1333         level=level,
#    1334         sort=sort,
#    1335         observed=False if observed is lib.no_default else observed,
#    1336         dropna=self.dropna,
#    1337     )
#    1339 if observed is lib.no_default:
#    1340     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File c:\Users\amarcosv\AppData\Local\miniforge3\envs\cellpose_mikala_pipeline\lib\site-packages\pandas\core\groupby\grouper.py:1043, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1041         in_axis, level, gpr = False, gpr, None
#    1042     else:
# -> 1043         raise KeyError(gpr)
#    1044 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1045     # Add key to exclusions
#    1046     exclusions.add(gpr.key)
#
# KeyError: 'dataset'
